# %% [markdown]
# ![banner](https://github.com/anopheles-genomic-surveillance/anopheles-genomic-surveillance.github.io/blob/master/docs/banner.jpg?raw=1)
#
# ***[Workshop 1](about) - Training course in data analysis for genomic surveillance of African malaria vectors***
#
# ---

# %% [markdown]
# # Module 2 - Accessing and exploring *Anopheles* genomic data
#
# **Theme: Data**
#
# This module provides an introduction to accessing and exploring data about *Anopheles* mosquito specimens collected in the field and submitted for whole-genome sequencing by MalariaGEN.

# %% [markdown]
# ## Learning objectives
#
# After completing this module, you will be able to:
#
# * Explain how *Anopheles* genomic data are generated.
# * Explain what types of data are available from MalariaGEN.
# * Explain where data from MalariaGEN are stored.
# * Use the `malariagen_data` Python package to access `Ag3.0` data in Google Cloud.
# * Explore the `Ag3.0` data release and summarise the mosquito samples for which genomic data are available using pivot tables and maps.

# %% [markdown]
# ## Lecture

# %% [markdown]
# ### English

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/c4vEBhZm3QI" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ### Français

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/TocNfwILAr8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Please note that the code in the cells below might differ from that shown in the video. This can happen because Python packages and their dependencies change due to updates, necessitating tweaks to the code.

# %% [markdown]
# ## Where do the data come from?
#
# * The data we'll be analysing in this training course where generated by multiple research groups collaborating as part of the Malaria Genomic Epidemiology Network ([MalariaGEN](https://www.malariagen.net)).
#
# * MalariaGEN is a collaborative programme providing access to genome sequencing and data processing services to support surveillance of malaria parasites and vectors.
#
# * Through this programme, members of research groups and disease control programmes in malaria-endemic countries work in partnership with the Wellcome Sanger Institute.
#
# * The basic workflow involves collecting mosquitoes, shipping them to sequencing facilities, preparing DNA samples and performing Illumina whole-genome sequencing, then processing the resulting data so they are ready for analysis, as shown below.

# %%
# %%html
# <img width="50%" height="50%" src="https://vobs-resources.cog.sanger.ac.uk/training/img/workshop-1/w1m2-1.png"/>
# Out:
# <img width="50%" height="50%" src="https://vobs-resources.cog.sanger.ac.uk/training/img/workshop-1/w1m2-1.png"/>

# %% [markdown]
# * Note that raw genome sequence data is not particularly useful by itself, and so the sequence reads are processed through **variant-calling pipelines** which identify different types of genetic variation between individual mosquitoes.
#
# * The results of variant-calling pipelines are then passed through a number of quality control, filtering and annotation steps to ensure data quality. We call this process **data curation**.
#
# * The **analysis-ready genome variation data** is then made available to all partners in the collaboration. This data can then be analysed to answer questions about the surveillance of mosquito populations, such as whether new forms of insecticide resistance are emerging and spreading.

# %% [markdown]
# ## What types of analysis-ready genomic data are available?
#
# * When DNA is passed from one generation of mosquitoes to the next, it undergoes **mutations**, which are errors in the DNA copying process. There are different types of mutations that can occur. These include:
#
#   * **Single Nucleotide Polymorphisms (SNPs)** - substitutions of a single letter in the DNA sequence
#
#   * **Copy Number Variants (CNVs)** - duplications or deletions of sections of a DNA sequence
#
# * Different variant calling pipelines are used to identify these different types of mutations.
#
# * It is also very useful to know whether combinations of mutations occur together in the same DNA sequence. In order to reconstruct this information, another pipeline is used to produce **phased haplotypes**.
#
# * To help make sense of the genomic data, we also need some data about the mosquitoes which were sequenced, such as the time and place of collection. This data is known as **sample metadata**.
#
# We will revisit CNVs and haplotypes in future workshops. For this workshop, we are only interested in SNPs and sample metadata.

# %%
# %%html
# <img width="80%" height="80%" src="https://vobs-resources.cog.sanger.ac.uk/training/img/workshop-1/w1m2-2.png"/>
# Out:
# <img width="80%" height="80%" src="https://vobs-resources.cog.sanger.ac.uk/training/img/workshop-1/w1m2-2.png"/>

# %% [markdown]
# ## Where are the data stored?
#
# * To make accessing these data as simple as possible, the resulting data are stored in Google Cloud using a service called Google Cloud Storage (GCS). These data can then be downloaded to any computer, or can be analysed within the cloud using cloud computing services like colab.
#
# * If you are using colab to access and analyses these data, then you don't need to download any data to your own computer or install any special software. You access colab through a web browser, and the code you run is executed on a different computer (a "virtual machine") which sits alongside the data in Google Cloud.

# %%
# %%html
# <img width="60%" height="60%" src="https://vobs-resources.cog.sanger.ac.uk/training/img/workshop-1/w1m2-3.png"/>
# Out:
# <img width="60%" height="60%" src="https://vobs-resources.cog.sanger.ac.uk/training/img/workshop-1/w1m2-3.png"/>

# %% [markdown]
# ## Accessing the `Ag3.0` data resource
#
# In this workshop we'll be accessing and analysing data from the [*Anopheles gambiae* 1000 Genomes Project phase 3 data resource](https://malariagen.github.io/vector-data/ag3/ag3.0.html), also known as "Ag3.0" for short. This includes data from whole-genome sequencing of 3,081 mosquitoes from 19 African countries.
#
# To set up your notebook to access these data, first install the [malariagen_data](https://github.com/malariagen/malariagen-data-python) package.

# %%
# %pip install -q --no-warn-conflicts malariagen_data
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 69.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.5/198.5 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 76.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.9/775.9 kB 46.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 95.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.9/25.9 MB 67.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 87.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.3/211.3 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 67.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 57.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 66.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.6 MB/s eta 0:00:00
#   Building wheel for dash-cytoscape (setup.py) ... done
#   Building wheel for asciitree (setup.py) ... done

# %% [markdown]
# Then import packages and set up access to *Anopheles gambiae* genomic data.

# %% [markdown]
# Note that authentication is required to access data through the package, please follow the instructions [here](https://malariagen.github.io/vector-data/vobs/vobs-data-access.html).

# %%
import malariagen_data

# %%
import plotly.io as pio
pio.renderers.default = "notebook+colab"
import plotly.express as px

# %%
ag3 = malariagen_data.Ag3()
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : gs://vo_agam_release_master_us_central1/
# Data releases available : 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 3.10, 3.11, 3.12, 3.13, 3.14
# Results cache           : None
# Cohorts analysis        : 20250131
# AIM analysis            : 20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 15.1.0
# Client location         : District of Columbia, United States (Google Cloud us-other)
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact support@malariagen.net. For API documentation see
# https://malariagen.github.io/malariagen-data-python/v15.1.0/Ag3.html

# %% [markdown]
# You can now access a number of different types of data through the `ag3` object. The full list of functions is available from the [Ag3 API docs](https://malariagen.github.io/vector-data/ag3/api.html). For the rest of this module, we are just going to look at sample metadata.

# %% [markdown]
# ## Loading sample metadata
#
# We can use the [`sample_metadata()`](https://malariagen.github.io/malariagen-data-python/latest/Ag3.html#sample-metadata-access) function to retrieve a pandas DataFrame containing metadata about all 3,081 samples in the Ag3.0 resource. In this DataFrame, each row represents one mosquito sample, and the columns such as `country` and `year` provide information about where the mosquito was originally collected.

# %%
df_samples = ag3.sample_metadata(sample_sets="3.0")
df_samples
# Out:
#      sample_id partner_sample_id      contributor    country location  year  \
# 0     AR0047-C            LUA047       Joao Pinto     Angola   Luanda  2009
# 1     AR0049-C            LUA049       Joao Pinto     Angola   Luanda  2009
# 2     AR0051-C            LUA051       Joao Pinto     Angola   Luanda  2009
# 3     AR0061-C            LUA061       Joao Pinto     Angola   Luanda  2009
# 4     AR0078-C            LUA078       Joao Pinto     Angola   Luanda  2009
# ...        ...               ...              ...        ...      ...   ...
# 3076  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 3077  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 3078  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 3079  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 3080  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
#       month  latitude  longitude sex_call  ... admin1_name admin1_iso  \
# 0         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 1         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 2         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 3         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 4         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# ...     ...       ...        ...      ...  ...         ...        ...
# 3076     -1    53.409     -2.969        F  ...         NaN        NaN
# 3077     -1    53.409     -2.969        M  ...         NaN        NaN
# 3078     -1    53.409     -2.969        M  ...         NaN        NaN
# 3079     -1    53.409     -2.969        F  ...         NaN        NaN
# 3080     -1    53.409     -2.969        M  ...         NaN        NaN
#
#       admin2_name       taxon cohort_admin1_year  cohort_admin1_month  \
# 0          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 1          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 2          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 3          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 4          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# ...           ...         ...                ...                  ...
# 3076          NaN  unassigned                NaN                  NaN
# 3077          NaN  unassigned                NaN                  NaN
# 3078          NaN  unassigned                NaN                  NaN
# 3079          NaN  unassigned                NaN                  NaN
# 3080          NaN  unassigned                NaN                  NaN
#
#      cohort_admin1_quarter       cohort_admin2_year  \
# 0      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 1      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 2      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 3      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 4      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# ...                    ...                      ...
# 3076                   NaN                      NaN
# 3077                   NaN                      NaN
# 3078                   NaN                      NaN
# 3079                   NaN                      NaN
# 3080                   NaN                      NaN
#
#              cohort_admin2_month       cohort_admin2_quarter
# 0     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 1     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 2     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 3     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 4     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# ...                          ...                         ...
# 3076                         NaN                         NaN
# 3077                         NaN                         NaN
# 3078                         NaN                         NaN
# 3079                         NaN                         NaN
# 3080                         NaN                         NaN
#
# [3081 rows x 57 columns]

# %% [markdown]
# ## Exploring sample metadata
#
# Let's use some pandas features such as [`groupby()`](https://pandas.pydata.org/docs/user_guide/groupby.html) and [`query()`](https://pandas.pydata.org/docs/user_guide/indexing.html#the-query-method) to explore the sample metadata.
#
# For example, let's first find out a bit more information about the different countries represented.

# %%
df_samples.groupby("country").size()
# Out:
# country
# Angola                               81
# Burkina Faso                        296
# Cameroon                            444
# Central African Republic             73
# Cote d'Ivoire                        80
# Democratic Republic of the Congo     76
# Equatorial Guinea                    10
# Gabon                                69
# Gambia, The                         279
# Ghana                               100
# Guinea                              136
# Guinea-Bissau                       101
# Kenya                                86
# Lab Cross                           297
# Malawi                               41
# Mali                                225
# Mayotte                              23
# Mozambique                           74
# Tanzania                            300
# Uganda                              290
# dtype: int64

# %% [markdown]
# We can then use the pandas query() function to select all samples from a given country. E.g., find all samples from Burkina Faso.

# %%
df_samples.query("country == 'Burkina Faso'")
# Out:
#      sample_id partner_sample_id    contributor       country      location  \
# 81   AB0085-Cx             BF2-4    Austin Burt  Burkina Faso          Pala
# 82   AB0086-Cx             BF2-6    Austin Burt  Burkina Faso          Pala
# 83    AB0087-C             BF3-3    Austin Burt  Burkina Faso  Bana Village
# 84    AB0088-C             BF3-5    Austin Burt  Burkina Faso  Bana Village
# 85   AB0089-Cx             BF3-8    Austin Burt  Burkina Faso  Bana Village
# ..         ...               ...            ...           ...           ...
# 372   AB0314-C              6775  Nora Besansky  Burkina Faso    Monomtenga
# 373   AB0315-C              6777  Nora Besansky  Burkina Faso    Monomtenga
# 374   AB0316-C              6779  Nora Besansky  Burkina Faso    Monomtenga
# 375   AB0318-C              5072  Nora Besansky  Burkina Faso    Monomtenga
# 376   AB0325-C              1403  Nora Besansky  Burkina Faso    Monomtenga
#
#      year  month  latitude  longitude sex_call  ...    admin1_name admin1_iso  \
# 81   2012      7    11.151     -4.235        F  ...  Hauts-Bassins      BF-09
# 82   2012      7    11.151     -4.235        F  ...  Hauts-Bassins      BF-09
# 83   2012      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 84   2012      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 85   2012      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# ..    ...    ...       ...        ...      ...  ...            ...        ...
# 372  2004      8    12.060     -1.170        F  ...     Centre-Sud      BF-07
# 373  2004      8    12.060     -1.170        F  ...     Centre-Sud      BF-07
# 374  2004      8    12.060     -1.170        F  ...     Centre-Sud      BF-07
# 375  2004      7    12.060     -1.170        F  ...     Centre-Sud      BF-07
# 376  2004      6    12.060     -1.170        F  ...     Centre-Sud      BF-07
#
#      admin2_name     taxon cohort_admin1_year cohort_admin1_month  \
# 81         Houet   gambiae    BF-09_gamb_2012  BF-09_gamb_2012_07
# 82         Houet   gambiae    BF-09_gamb_2012  BF-09_gamb_2012_07
# 83         Houet  coluzzii    BF-09_colu_2012  BF-09_colu_2012_07
# 84         Houet  coluzzii    BF-09_colu_2012  BF-09_colu_2012_07
# 85         Houet  coluzzii    BF-09_colu_2012  BF-09_colu_2012_07
# ..           ...       ...                ...                 ...
# 372       Bazega   gambiae    BF-07_gamb_2004  BF-07_gamb_2004_08
# 373       Bazega   gambiae    BF-07_gamb_2004  BF-07_gamb_2004_08
# 374       Bazega   gambiae    BF-07_gamb_2004  BF-07_gamb_2004_08
# 375       Bazega   gambiae    BF-07_gamb_2004  BF-07_gamb_2004_07
# 376       Bazega   gambiae    BF-07_gamb_2004  BF-07_gamb_2004_06
#
#     cohort_admin1_quarter      cohort_admin2_year        cohort_admin2_month  \
# 81     BF-09_gamb_2012_Q3   BF-09_Houet_gamb_2012   BF-09_Houet_gamb_2012_07
# 82     BF-09_gamb_2012_Q3   BF-09_Houet_gamb_2012   BF-09_Houet_gamb_2012_07
# 83     BF-09_colu_2012_Q3   BF-09_Houet_colu_2012   BF-09_Houet_colu_2012_07
# 84     BF-09_colu_2012_Q3   BF-09_Houet_colu_2012   BF-09_Houet_colu_2012_07
# 85     BF-09_colu_2012_Q3   BF-09_Houet_colu_2012   BF-09_Houet_colu_2012_07
# ..                    ...                     ...                        ...
# 372    BF-07_gamb_2004_Q3  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_08
# 373    BF-07_gamb_2004_Q3  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_08
# 374    BF-07_gamb_2004_Q3  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_08
# 375    BF-07_gamb_2004_Q3  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_07
# 376    BF-07_gamb_2004_Q2  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_06
#
#          cohort_admin2_quarter
# 81    BF-09_Houet_gamb_2012_Q3
# 82    BF-09_Houet_gamb_2012_Q3
# 83    BF-09_Houet_colu_2012_Q3
# 84    BF-09_Houet_colu_2012_Q3
# 85    BF-09_Houet_colu_2012_Q3
# ..                         ...
# 372  BF-07_Bazega_gamb_2004_Q3
# 373  BF-07_Bazega_gamb_2004_Q3
# 374  BF-07_Bazega_gamb_2004_Q3
# 375  BF-07_Bazega_gamb_2004_Q3
# 376  BF-07_Bazega_gamb_2004_Q2
#
# [296 rows x 57 columns]

# %% [markdown]
# From a quick glance at the preview above, we can see there are samples collected in different years. Let's summarise that.

# %%
df_samples.query("country == 'Burkina Faso'").groupby("year").size()
# Out:
# year
# 2004     13
# 2012    181
# 2014    102
# dtype: int64

# %% [markdown]
# If we wanted to now inspect the samples collected from Burkina Faso in 2014, we could combine these conditions in a query.

# %%
df_samples.query("country == 'Burkina Faso' and year == 2014")
# Out:
#     sample_id partner_sample_id  contributor       country        location  \
# 262  AB0326-C            BF18-1  Austin Burt  Burkina Faso    Bana Village
# 263  AB0327-C            BF18-3  Austin Burt  Burkina Faso    Bana Village
# 264  AB0328-C            BF18-4  Austin Burt  Burkina Faso    Bana Village
# 265  AB0329-C            BF18-5  Austin Burt  Burkina Faso    Bana Village
# 266  AB0330-C            BF18-6  Austin Burt  Burkina Faso    Bana Village
# ..        ...               ...          ...           ...             ...
# 359  AB0533-C           BF13-18  Austin Burt  Burkina Faso  Souroukoudinga
# 360  AB0536-C           BF13-31  Austin Burt  Burkina Faso  Souroukoudinga
# 361  AB0537-C           BF13-32  Austin Burt  Burkina Faso  Souroukoudinga
# 362  AB0538-C           BF13-33  Austin Burt  Burkina Faso  Souroukoudinga
# 363  AB0408-C           BF14-20  Austin Burt  Burkina Faso    Bana Village
#
#      year  month  latitude  longitude sex_call  ...    admin1_name admin1_iso  \
# 262  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 263  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 264  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 265  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 266  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# ..    ...    ...       ...        ...      ...  ...            ...        ...
# 359  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 360  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 361  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 362  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 363  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
#
#      admin2_name     taxon cohort_admin1_year cohort_admin1_month  \
# 262        Houet  coluzzii    BF-09_colu_2014  BF-09_colu_2014_07
# 263        Houet  coluzzii    BF-09_colu_2014  BF-09_colu_2014_07
# 264        Houet  coluzzii    BF-09_colu_2014  BF-09_colu_2014_07
# 265        Houet  coluzzii    BF-09_colu_2014  BF-09_colu_2014_07
# 266        Houet  coluzzii    BF-09_colu_2014  BF-09_colu_2014_07
# ..           ...       ...                ...                 ...
# 359        Houet   gambiae    BF-09_gamb_2014  BF-09_gamb_2014_07
# 360        Houet   gambiae    BF-09_gamb_2014  BF-09_gamb_2014_07
# 361        Houet   gambiae    BF-09_gamb_2014  BF-09_gamb_2014_07
# 362        Houet   gambiae    BF-09_gamb_2014  BF-09_gamb_2014_07
# 363        Houet  coluzzii    BF-09_colu_2014  BF-09_colu_2014_07
#
#     cohort_admin1_quarter     cohort_admin2_year       cohort_admin2_month  \
# 262    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 263    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 264    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 265    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 266    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# ..                    ...                    ...                       ...
# 359    BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
# 360    BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
# 361    BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
# 362    BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
# 363    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
#
#         cohort_admin2_quarter
# 262  BF-09_Houet_colu_2014_Q3
# 263  BF-09_Houet_colu_2014_Q3
# 264  BF-09_Houet_colu_2014_Q3
# 265  BF-09_Houet_colu_2014_Q3
# 266  BF-09_Houet_colu_2014_Q3
# ..                        ...
# 359  BF-09_Houet_gamb_2014_Q3
# 360  BF-09_Houet_gamb_2014_Q3
# 361  BF-09_Houet_gamb_2014_Q3
# 362  BF-09_Houet_gamb_2014_Q3
# 363  BF-09_Houet_colu_2014_Q3
#
# [102 rows x 57 columns]

# %% [markdown]
# Finally, let's break this down by mosquito species.

# %%
df_samples.query("country == 'Burkina Faso' and year == 2014").groupby("taxon").size()
# Out:
# taxon
# arabiensis     3
# coluzzii      53
# gambiae       46
# dtype: int64

# %% [markdown]
# ## Summarising sample metadata with pivot tables
#
# In the examples above we explored a part of the sample metadata, but it can also be useful to get an overall summary of how many samples have been sequenced, broken down by time and place of collection and mosquito species. For that kind of summary the [`pivot_table()`](https://pandas.pydata.org/docs/user_guide/reshaping.html#pivot-tables) function is useful.
#
# Let's start by summarising the number of mosquitoes by country and species (taxon).

# %%
pivot_country_taxon = (
    df_samples
    .pivot_table(
        index="country",
        columns="taxon",
        values="sample_id",
        aggfunc="count",
        fill_value=0
    )
)
pivot_country_taxon
# Out:
# taxon                             arabiensis  bissau  coluzzii  gambiae  gcx3  \
# country
# Angola                                     0       0        81        0     0
# Burkina Faso                               3       0       135      158     0
# Cameroon                                   2       0        26      416     0
# Central African Republic                   0       0        18       55     0
# Cote d'Ivoire                              0       0        80        0     0
# Democratic Republic of the Congo           0       0         0       76     0
# Equatorial Guinea                          0       0         0       10     0
# Gabon                                      0       0         0       69     0
# Gambia, The                                0      77       200        2     0
# Ghana                                      0       0        64       36     0
# Guinea                                     0       0        11      125     0
# Guinea-Bissau                              0      93         0        8     0
# Kenya                                     13       0         0       19    54
# Lab Cross                                  0       0         0        0     0
# Malawi                                    41       0         0        0     0
# Mali                                       2       0        90      131     0
# Mayotte                                    0       0         0       23     0
# Mozambique                                 0       0         0       74     0
# Tanzania                                 225       0         0       64    11
# Uganda                                    82       0         0      207     0
#
# taxon                             unassigned
# country
# Angola                                     0
# Burkina Faso                               0
# Cameroon                                   0
# Central African Republic                   0
# Cote d'Ivoire                              0
# Democratic Republic of the Congo           0
# Equatorial Guinea                          0
# Gabon                                      0
# Gambia, The                                0
# Ghana                                      0
# Guinea                                     0
# Guinea-Bissau                              0
# Kenya                                      0
# Lab Cross                                297
# Malawi                                     0
# Mali                                       2
# Mayotte                                    0
# Mozambique                                 0
# Tanzania                                   0
# Uganda                                     1

# %% [markdown]
# We could also turn this into a bar chart.

# %%
fig = px.bar(pivot_country_taxon, height=600, width=800)
fig.update_layout(
    title="Ag3.0 genomes sequenced",
    yaxis_title="no. genomes",
)
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Mosquitoes were also sampled in different years. Let's make a new pivot table, breaking down by country, year and taxon.

# %%
pivot_country_year_taxon = (
    df_samples
    .pivot_table(
        index=["country", "year"],
        columns=["taxon"],
        values="sample_id",
        aggfunc="count",
        fill_value=0
    )
)
pivot_country_year_taxon
# Out:
# taxon                                   arabiensis  bissau  coluzzii  gambiae  \
# country                          year
# Angola                            2009           0       0        81        0
# Burkina Faso                      2004           0       0         0       13
#                                   2012           0       0        82       99
#                                   2014           3       0        53       46
# Cameroon                          2005           0       0         7       90
#                                   2009           0       0         0      303
#                                   2013           2       0        19       23
# Central African Republic          1993           0       0         5        2
#                                   1994           0       0        13       53
# Cote d'Ivoire                     2012           0       0        80        0
# Democratic Republic of the Congo  2015           0       0         0       76
# Equatorial Guinea                 2002           0       0         0       10
# Gabon                             2000           0       0         0       69
# Gambia, The                       2006           0       9        22        0
#                                   2011           0      68         6        0
#                                   2012           0       0       172        2
# Ghana                             2012           0       0        64       36
# Guinea                            2012           0       0        11      125
# Guinea-Bissau                     2010           0      93         0        8
# Kenya                             2000           0       0         0       19
#                                   2007           3       0         0        0
#                                   2012          10       0         0        0
# Lab Cross                        -1              0       0         0        0
# Malawi                            2015          41       0         0        0
# Mali                              2004           2       0        36       33
#                                   2012           0       0        27       65
#                                   2014           0       0        27       33
# Mayotte                           2011           0       0         0       23
# Mozambique                        2003           0       0         0        3
#                                   2004           0       0         0       71
# Tanzania                          2012          87       0         0        0
#                                   2013           1       0         0       32
#                                   2015         137       0         0       32
# Uganda                            2012          82       0         0      207
#
# taxon                                   gcx3  unassigned
# country                          year
# Angola                            2009     0           0
# Burkina Faso                      2004     0           0
#                                   2012     0           0
#                                   2014     0           0
# Cameroon                          2005     0           0
#                                   2009     0           0
#                                   2013     0           0
# Central African Republic          1993     0           0
#                                   1994     0           0
# Cote d'Ivoire                     2012     0           0
# Democratic Republic of the Congo  2015     0           0
# Equatorial Guinea                 2002     0           0
# Gabon                             2000     0           0
# Gambia, The                       2006     0           0
#                                   2011     0           0
#                                   2012     0           0
# Ghana                             2012     0           0
# Guinea                            2012     0           0
# Guinea-Bissau                     2010     0           0
# Kenya                             2000     0           0
#                                   2007     0           0
#                                   2012    54           0
# Lab Cross                        -1        0         297
# Malawi                            2015     0           0
# Mali                              2004     0           0
#                                   2012     0           2
#                                   2014     0           0
# Mayotte                           2011     0           0
# Mozambique                        2003     0           0
#                                   2004     0           0
# Tanzania                          2012     0           0
#                                   2013    10           0
#                                   2015     1           0
# Uganda                            2012     0           1

# %% [markdown]
# For some countries there are data from multiple collection sites. Let's inspect that for Burkina Faso by applying a query then creating a pivot table.

# %%
pivot_location_year_taxon_bf = (
    df_samples
    .query("country == 'Burkina Faso'")
    .pivot_table(
        index=["country", "admin1_name", "admin2_name", "location", "year"],
        columns=["taxon"],
        values="sample_id",
        aggfunc="count",
        fill_value=0
    )
)
pivot_location_year_taxon_bf
# Out:
# taxon                                                       arabiensis  \
# country      admin1_name   admin2_name location       year
# Burkina Faso Centre-Sud    Bazega      Monomtenga     2004           0
#              Hauts-Bassins Houet       Bana Village   2012           0
#                                                       2014           1
#                                        Pala           2012           0
#                                                       2014           2
#                                        Souroukoudinga 2012           0
#                                                       2014           0
#
# taxon                                                       coluzzii  gambiae
# country      admin1_name   admin2_name location       year
# Burkina Faso Centre-Sud    Bazega      Monomtenga     2004         0       13
#              Hauts-Bassins Houet       Bana Village   2012        42       23
#                                                       2014        47       15
#                                        Pala           2012        11       48
#                                                       2014         0       16
#                                        Souroukoudinga 2012        29       28
#                                                       2014         6       15

# %% [markdown]
# We can see there are four collection sites in Burkina Faso.

# %% [markdown]
# ## Plotting maps of sampling locations
#
# To explore the different mosquito collection locations it can also be useful to plot some maps. You can plot maps within a notebook using various packages such as [ipyleaflet](https://ipyleaflet.readthedocs.io/en/latest/). Let's install the ipyleaflet package.

# %%
# %pip install -qq ipyleaflet

# %% [markdown]
# Now import some useful functions from ipyleaflet.

# %%
import ipyleaflet

# %% [markdown]
# Creating an interactive map is very straightforward, using the [Map()](https://ipyleaflet.readthedocs.io/en/latest/map_and_basemaps/map.html) function. Here is a world map centered on Africa. Note that this is an interactive map, you can pan and zoom.

# %%
m = ipyleaflet.Map(
    basemap=ipyleaflet.basemaps.OpenStreetMap.Mapnik,
    center=[0, 20],
    zoom=3,

)
m
# Out:
# Map(center=[0, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# Let's now plot a map, adding in markers for all of the locations where we have mosquitoes. First create a pivot table with the location data we need.

# %%
pivot_location_taxon = (
    df_samples
    .pivot_table(
        index=["country", "location", "latitude", "longitude"],
        columns=["taxon"],
        values="sample_id",
        aggfunc="count",
        fill_value=0,
    )
)

pivot_location_taxon
# Out:
# taxon                                           arabiensis  bissau  coluzzii  \
# country      location       latitude longitude
# Angola       Luanda         -8.884    13.302             0       0        81
# Burkina Faso Bana Village    11.233  -4.472              1       0        89
#              Monomtenga      12.060  -1.170              0       0         0
#              Pala            11.151  -4.235              2       0        11
#              Souroukoudinga  11.238  -4.235              0       0        35
# ...                                                    ...     ...       ...
# Tanzania     Muheza         -4.940    38.948             1       0         0
#              Muleba         -1.962    31.621           137       0         0
#              Tarime         -1.431    34.199            47       0         0
# Uganda       Kihihi         -0.751    29.701             1       0         0
#              Nagongera       0.770    34.026            81       0         0
#
# taxon                                           gambiae  gcx3  unassigned
# country      location       latitude longitude
# Angola       Luanda         -8.884    13.302          0     0           0
# Burkina Faso Bana Village    11.233  -4.472          38     0           0
#              Monomtenga      12.060  -1.170          13     0           0
#              Pala            11.151  -4.235          64     0           0
#              Souroukoudinga  11.238  -4.235          43     0           0
# ...                                                 ...   ...         ...
# Tanzania     Muheza         -4.940    38.948         32    10           0
#              Muleba         -1.962    31.621         32     1           0
#              Tarime         -1.431    34.199          0     0           0
# Uganda       Kihihi         -0.751    29.701         95     0           0
#              Nagongera       0.770    34.026        112     0           1
#
# [127 rows x 6 columns]

# %% [markdown]
# Now create a map with markers.

# %%
# create a map
m = ipyleaflet.Map(
    basemap=ipyleaflet.basemaps.OpenStreetMap.Mapnik,
    center=[0, 20],
    zoom=3,
)

# add markers for sampling locations
for row in pivot_location_taxon.reset_index().itertuples():
    title = (
        f"{row.location}, {row.country} ({row.latitude:.3f}, {row.longitude:.3f})\n"
        f"{row.gambiae} gambiae, {row.coluzzii} coluzzii, {row.arabiensis} arabiensis"
    )
    marker = ipyleaflet.Marker(
        location=(row.latitude, row.longitude),
        draggable=False,
        title=title,
    )
    m.add_layer(marker)

# add a scale bar
m.add_control(ipyleaflet.ScaleControl(position="bottomleft"))

# display the map
m
# Out:
# Map(center=[0, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# Try hovering over the markers, you should see some text with a summary of how many samples are available by species.

# %% [markdown]
# ## Practical exercises
#
# ### English
#
# 1. [Open this notebook in Google Colab](https://colab.research.google.com/github/anopheles-genomic-surveillance/anopheles-genomic-surveillance.github.io/blob/master/docs/workshop-1/module-2-sample-metadata.ipynb) and run it for yourself from top to bottom. Hint: click the rocket icon (<i class="fas fa-rocket"></i>) at the top of the page, then select “Colab” from the drop-down menu. When colab opens, click the "Edit" menu, then select "Clear all outputs", then begin running the cells.
# 1. Find out how many mosquito specimens are available for each of the different *Anopheles* species represented. Hint: try grouping the sample metadata dataframe by the "taxon" column, then calling the `size()` method.
# 1. Make a pivot table that shows how many samples are available in the Ag3.0 resource that were collected in Mali, summarised by year, location and taxon. Now try Cameroon, or any other country of interest.
# 1. How many countries are there for which we have some samples of *Anopheles coluzzii*? What about *Anopheles arabiensis* and *Anopheles gambiae*? Hint: Make a pivot table by country and taxon, and then query it.
# 1. Plot a map of all sampling locations, changing the `basemap` parameter to show a different background map. Hint: see the [ipyleaflet basemaps documentation](https://ipyleaflet.readthedocs.io/en/latest/map_and_basemaps/basemaps.html) for a list of available options.
# 1. Plot a map that starts centered and zoomed in to Uganda, or any other country of interest. Hint: change the `center` and `zoom` parameters when calling the ipyleaflet `Map()` function.
# 1. Plot a map showing only locations where we have samples of *Anopheles coluzzii*. Now try *Anopheles arabiensis* or *Anopheles gambiae*.
# 1. If you feel like a challenge, plot a map with markers for sampling locations, and add a popup to each marker showing a pivot table of how many samples were collected by year and species.
#
# ### Français
#
# 1. [Ouvrir ce notebook dans Google Colab](https://colab.research.google.com/github/anopheles-genomic-surveillance/anopheles-genomic-surveillance.github.io/blob/master/docs/workshop-1/module-2-sample-metadata.ipynb) et exécuter le vous-même du début à la fin. Indice: cliquer sur l'icone fusée (<i class="fas fa-rocket"></i>) au sommet de la page et sélectionner "Colab" dans le menu déroulant. Quand Colab s'ouvre, cliquer sur le menu "Edit" et sélectionner "Clear all outputs", commencer ensuite à exéuter les cellules.
# 1. Trouver combien de moustiques sont disponibles pour chacune des différentes espèces d'Anophèles représentées. Indice: essayer de grouper le dataframe des métadonnées des échantillons selon la colonne "taxon", ensuite utiliser la méthode `size()`.
# 1. Créer une table à pivôt qui montre combien de moustiques capturés au Mali sont présents dans Ag3.0, résummés par année, lieu de capture et taxon. Essayer ensuite le Cameroun ou autre pays de votre choix.
# 1. Pour combien de pays avons nous des *Anophèles coluzzii*? Même question pour *Anophèles arabiensis* et *Anophèles gambiae*? Indice: créer une table à pivôt par pays et taxon et utiliser une requête.
# 1. Créer une carte de tous les lieux de capture utilisant une autre basemap pour avoir un fond différent. Indice: regarder la [documentation d'ipyleaflet basemaps](https://ipyleaflet.readthedocs.io/en/latest/map_and_basemaps/basemaps.html) pour une liste des options disponibles.
# 1. Créer une carte centrée et zoomée sur l'Ouganda ou un autre pays de votre choix. Indice: modifier les paramètres center et zoom quand vous utilisez la fonction `Map()` d'ipyleaflet.
# 1. Créer une carte ne montrant que les lieux de capture où des *Anophèles coluzzii* ont été capturés. Faire la même chose pour les *Anophèles arabiensis* ou les *Anophèles gambiae*.
# 1. Si vous souhaitez un défi, créer une carte avec un marqueur pour chaque lieu de capture et ajouter un pop-up à chaque marqueur montrant une table à pivôt donnant le nombre de moustiques par année et taxon.

# %% [markdown]
# ##### Question 2 Find out how many mosquito specimens are available for each of the different Anopheles species represented. Hint: try grouping the sample metadata dataframe by the "taxon" column, then calling the size() method.

# %%
# Find out how many mosquito specimens are available for each of the different Anopheles species represented.

df_samples.groupby("taxon").size()
# Out:
# taxon
# arabiensis     368
# bissau         170
# coluzzii       705
# gambiae       1473
# gcx3            65
# unassigned     300
# dtype: int64

# %%
# Another approach
species_counts = df_samples.groupby("taxon").size()
print(species_counts)
# Out:
# taxon
# arabiensis     368
# bissau         170
# coluzzii       705
# gambiae       1473
# gcx3            65
# unassigned     300
# dtype: int64

# %% [markdown]
# ##### Question 3. Make a pivot table that shows how many samples are available in the Ag3.0 resource that were collected in Mali, summarised by year, location and taxon. Now try Cameroon, or any other country of interest.

# %%
#Pivot table of samples collected in Mali by year, location and taxon

df_samples.query("country == 'Mali'").pivot_table(
        index=["country", "year", "location"],
        columns=["taxon"],
        values="sample_id",
        aggfunc="count",
        fill_value=0,
    )
# Out:
# taxon                        arabiensis  coluzzii  gambiae  unassigned
# country year location
# Mali    2004 Bancoumana               0         0        9           0
#              Douna                    1        19        0           0
#              Fanzana                  1         6        1           0
#              Kela                     0         0       23           0
#              Moribobougou             0         7        0           0
#              N'Gabakoro               0         4        0           0
#         2012 Takan                    0        25        5           1
#              Toumani Oulena           0         2       60           1
#         2014 Kababougou               0        12       28           0
#              Ouassorola               0         9        4           0
#              Tieneguebougou           0         6        1           0

# %%
# Pivot table of samples collected in Cameroon by year, location and taxon

df_samples.query("country == 'Cameroon'").pivot_table(
        index=["country","year","location"],
        columns = ["taxon"],
        values = "sample_id",
        aggfunc="count",
        fill_value=0,
        )
# Out:
# taxon                      arabiensis  coluzzii  gambiae
# country  year location
# Cameroon 2005 Ahala                 0         0        4
#               Avebe                 0         0        1
#               Badankali             0         1        0
#               Badjawa               0         0        3
#               Balda Bouri           0         0        2
# ...                               ...       ...      ...
#          2013 Mfelap                0         0        1
#               Mgbandji              0         0        1
#               Nkolondom             0         5        5
#               Tibati                0         2        2
#               Yaounde               0         7        0
#
# [75 rows x 3 columns]

# %%
#Pivot table of samples collected in Uganda by year, location and taxon

df_samples.query("country == 'Uganda'").pivot_table(
        index=["country","year","location"],
        columns = ["taxon"],
        values = "sample_id",
        aggfunc="count",
        fill_value=0,
        )
# Out:
# taxon                   arabiensis  gambiae  unassigned
# country year location
# Uganda  2012 Kihihi              1       95           0
#              Nagongera          81      112           1

# %% [markdown]
# ##### Question 4. How many countries are there for which we have some samples of Anopheles coluzzii? What about Anopheles arabiensis and Anopheles gambiae? Hint: Make a pivot table by country and taxon, and then query it.

# %%
#create a pivot table
pivot_country_taxon = (
    df_samples
    .pivot_table(
        index=["country"],
        columns=["taxon"],
        values="sample_id",
        aggfunc="count",
        fill_value=0,
    )
)

# Query the pivot table for each moquito species
coluzzii_countries = pivot_country_taxon.query("coluzzii > 0")
arabiensis_countries = pivot_country_taxon.query("arabiensis > 0")
gambiae_countries = pivot_country_taxon.query("gambiae > 0")

# Outputs
print(f"Number of countries with Anopheles coluzzii: {len(coluzzii_countries)}")
print(f"Number of countries with Anopheles arabiensis: {len(arabiensis_countries)}")
print(f"Number of countries with Anopheles gambiae: {len(gambiae_countries)}")
# Out:
# Number of countries with Anopheles coluzzii: 9
# Number of countries with Anopheles arabiensis: 7
# Number of countries with Anopheles gambiae: 16

# %% [markdown]
# #### Question 5. Plot a map of all sampling locations, changing the basemap parameter to show a different background map. Hint: see the ipyleaflet basemaps documentation for a list of available options.

# %%
# %pip install ipyleaflet
# Out:
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.11/dist-packages (0.19.2)
# Requirement already satisfied: branca>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (0.8.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (7.7.1)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (2025.1.0)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from branca>=0.5.0->ipyleaflet) (3.1.6)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.13)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (3.0.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (2.8.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.24.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.13.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.3.1)

# %%
# create a map
m = ipyleaflet.Map(
    basemap=ipyleaflet.basemaps.OpenStreetMap.Mapnik,
    center=[0, 20],
    zoom=3,
)
# add markers for sampling locations
for row in pivot_location_taxon.reset_index().itertuples():
    title = (
        f"{row.location}, {row.country} ({row.latitude:.3f}, {row.longitude:.3f})\n"
        f"{row.gambiae} gambiae, {row.coluzzii} coluzzii, {row.arabiensis} arabiensis"
    )
    marker = ipyleaflet.Marker(
        location=(row.latitude, row.longitude),
        draggable=False,
        title=title,
    )
    m.add_layer(marker)

# add a scale bar
m.add_control(ipyleaflet.ScaleControl(position="bottomleft"))

# display the map
m
# Out:
# Map(center=[0, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ##### Question 6.Plot a map that starts centered and zoomed in to Uganda, or any other country of interest. Hint: change the center and zoom parameters when calling the ipyleaflet Map() function.

# %%
# create a map centered on Uganda
m = ipyleaflet.Map(
    basemap=ipyleaflet.basemaps.OpenStreetMap.Mapnik,
    center=[1.3733, 32.2903],  # coordinates of Uganda
    zoom=7,  # Adjust zoom level as needed
)
# add markers for sampling locations
for row in pivot_location_taxon.reset_index().itertuples():
    title = (
        f"{row.location}, {row.country} ({row.latitude:.3f}, {row.longitude:.3f})\n"
        f"{row.gambiae} gambiae, {row.coluzzii} coluzzii, {row.arabiensis} arabiensis"
    )
    marker = ipyleaflet.Marker(
        location=(row.latitude, row.longitude),
        draggable=False,
        title=title,
    )
    m.add_layer(marker)

# add a scale bar
m.add_control(ipyleaflet.ScaleControl(position="bottomleft"))

# display the map
m
# Out:
# Map(center=[1.3733, 32.2903], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %% [markdown]
# ##### Question 7.Plot a map showing only locations where we have samples of Anopheles coluzzii. Now try Anopheles arabiensis or Anopheles gambiae.

# %%
# create a map
m = ipyleaflet.Map(
    basemap=ipyleaflet.basemaps.OpenStreetMap.Mapnik,
    center=[0, 20],
    zoom=3,
)

# add markers for sampling locations of Anopheles coluzzii
for row in pivot_location_taxon.reset_index().itertuples():
    if row.coluzzii > 0:  # Check if coluzzii samples exist at this location
        title = (
            f"{row.location}, {row.country} ({row.latitude:.3f}, {row.longitude:.3f})\n"
            f"{row.gambiae} gambiae, {row.coluzzii} coluzzii, {row.arabiensis} arabiensis"
        )
        marker = ipyleaflet.Marker(
            location=(row.latitude, row.longitude),
            draggable=False,
            title=title,
        )
        m.add_layer(marker)

# add a scale bar
m.add_control(ipyleaflet.ScaleControl(position="bottomleft"))

# display the map
m


# Now try Anopheles arabiensis
m = ipyleaflet.Map(
    basemap=ipyleaflet.basemaps.OpenStreetMap.Mapnik,
    center=[0, 20],
    zoom=3,
)

for row in pivot_location_taxon.reset_index().itertuples():
    if row.arabiensis > 0:
        title = (
            f"{row.location}, {row.country} ({row.latitude:.3f}, {row.longitude:.3f})\n"
            f"{row.gambiae} gambiae, {row.coluzzii} coluzzii, {row.arabiensis} arabiensis"
        )
        marker = ipyleaflet.Marker(
            location=(row.latitude, row.longitude),
            draggable=False,
            title=title,
        )
        m.add_layer(marker)

m.add_control(ipyleaflet.ScaleControl(position="bottomleft"))
m
# Out:
# Map(center=[0, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ##### Question 8. If you feel like a challenge, plot a map with markers for sampling locations, and add a popup to each marker showing a pivot table of how many samples were collected by year and species.

# %%
import pandas as pd
import ipyleaflet
from ipyleaflet import Map, Marker, Popup
from ipywidgets import HTML

# Create the pivot table for the popup
pivot_location_year_taxon = (
    df_samples
    .pivot_table(
        index=["year"],
        columns=["taxon"],
        values="sample_id",
        aggfunc="count",
        fill_value=0
    )
)

# We need location data to place markers
# Let's assume we have latitude and longitude columns in df_samples
location_data = df_samples[['year', 'latitude', 'longitude']].drop_duplicates()

# Create a map
m = Map(
    basemap=ipyleaflet.basemaps.OpenStreetMap.Mapnik,
    center=[0, 20],
    zoom=3
)

# Add markers for sampling locations with popups
for _, row in location_data.iterrows():
    try:
        marker = Marker(location=(row['latitude'], row['longitude']))

        # Create the popup content as an HTML table for this year
        year_data = pivot_location_year_taxon.loc[[row['year']]]
        popup_content = year_data.to_html()

        popup = Popup(
            location=(row['latitude'], row['longitude']),
            child=HTML(value=popup_content),
            close_button=False,
            auto_close=False,
        )

        marker.popup = popup
        m.add_layer(marker)
    except Exception as e:
        print(f"Error processing row {row}: {e}")

m
# Out:
# Map(center=[0, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
# !git clone https://github.com/Jadamoureen/genomic_surveillance_malaria_vectors.git
# Out:
# Cloning into 'genomic_surveillance_malaria_vectors'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 1.33 MiB | 10.06 MiB/s, done.
