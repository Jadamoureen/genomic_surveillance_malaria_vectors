# %% [markdown]
# # Workshop 1 - Module 1
#
# ### Connect Github to Google Colab

# %%
# !git config --global user.name "jadamoureen"
# !git config --global user.email "moureen.caroline@gmail.com"

# %% [markdown]
# ### Clone Github Repo

# %%
username ="jadamoureen"
repo = "genomic_surveillance_malaria_vectors"

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'genomic_surveillance_malaria_vectors'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %% [markdown]
# #### Commit and Push changes back to Github Repo

# %%
cd /content/genomic_surveillance_malaria_vectors
# Out:
# /content/genomic_surveillance_malaria_vectors

# %%
! git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
! git add .

# %%
! git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ##### Code Cells

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ##### Inspecting a Variable

# %%
foo = 42 #foo is a variable

# %%
foo
# Out:
# 42

# %%
foo = foo + 1
foo # calling the variable without using the print function
# Out:
# 43

# %%
#type function inspects what type of object is assigned to the variable

type(foo)
# Out:
# int

# %% [markdown]
# ### Adding images

# %%
# !echo '[Anopheles gambiae](https://upload.wikimedia.org/wikipedia/commons/0/0a/AnophelesGambiaemosquito.jpg)'
# Out:
# [Anopheles gambiae](https://upload.wikimedia.org/wikipedia/commons/0/0a/AnophelesGambiaemosquito.jpg)

# %%
from IPython.display import Image, display

display(Image(url="https://upload.wikimedia.org/wikipedia/commons/0/0a/AnophelesGambiaemosquito.jpg"))
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/0a/AnophelesGambiaemosquito.jpg"/>

# %% [markdown]
# #### Coding Basics
#
# ##### Math

# %%
#Arithmetic
x = 10
y = 3 + (4 * x) - 1
y
# Out:
# 42

# %% [markdown]
# ##### For loops

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ##### Defining and Calling Functions

# %%
def greet(name):
  print(f"Hello, {name}!")

# %%
greet("Moureen Caroline O")
# Out:
# Hello, Moureen Caroline O!

# %% [markdown]
# #### Importing and installing Python packages

# %%
import numpy as np

# %%
y = np.random.randint(low=0, high=100, size=10)
print(y)
# Out:
# [33 12 32  0 61 49 62 14  3 70]

# %% [markdown]
# ##### Installing the malaria gen package

# %%
pip install malariagen-data
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 31.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.5/198.5 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.9/775.9 kB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 44.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.9/25.9 MB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.3/211.3 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 49.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 42.8 MB/s eta 0:00:00
# ...

# %%
import malariagen_data

# %%
# start using the package

ag3 = malariagen_data.Ag3()
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : gs://vo_agam_release_master_us_central1
# Data releases available : 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 3.10, 3.11, 3.12, 3.13, 3.14
# Results cache           : None
# Cohorts analysis        : 20250131
# AIM analysis            : 20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 15.1.0
# Client location         : Iowa, United States (Google Cloud us-central1)
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact support@malariagen.net. For API documentation see
# https://malariagen.github.io/malariagen-data-python/v15.1.0/Ag3.html

# %% [markdown]
# ##### Viewing dataframes

# %%
df_samples = ag3.sample_metadata(sample_sets="3.0")
df_samples
# Out:
#      sample_id partner_sample_id      contributor    country location  year  \
# 0     AR0047-C            LUA047       Joao Pinto     Angola   Luanda  2009
# 1     AR0049-C            LUA049       Joao Pinto     Angola   Luanda  2009
# 2     AR0051-C            LUA051       Joao Pinto     Angola   Luanda  2009
# 3     AR0061-C            LUA061       Joao Pinto     Angola   Luanda  2009
# 4     AR0078-C            LUA078       Joao Pinto     Angola   Luanda  2009
# ...        ...               ...              ...        ...      ...   ...
# 3076  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 3077  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 3078  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 3079  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 3080  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
# ...

# %%
type(df_samples)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##### Creating Plots

# %%
x =np.random.binomial(n=30, p=0.5, size=10_000)
x
# Out:
# array([16, 20, 20, ..., 16, 13, 11])

# %% [markdown]
# ##### Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()
ax.hist(x)
ax.set_xlabel("x")
ax.set_ylabel("Count")
ax.set_title("The Binomial Distribution");

# %% [markdown]
# ##### Plotly Express

# %%
import plotly.io as pio
pio.renderers.default = "notebook+colab"
import plotly.express as px

# %%
fig = px.histogram(
      x=x,
      title="The Binomial Distribution",
      width=600,
      height=400
                   )
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##### Bokeh

# %%
import bokeh.plotting as bkplt
import bokeh.io as bkio
bkio.output_notebook()

# %%
fig = bkplt.figure(title="The Binomial Distribution", width=600, height=400)
hist, edges = np.histogram(x)
fig.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:])
bkplt.show(fig)
# Out:
#   <div id="eb84d4a7-5efa-4351-9cd7-2597a8b969bf" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ##### Accessing help documentation(docstrings)

# %%
np.random.binomial?

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
! git commit -a -m "Workshop 1-module 1"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# Everything up-to-date

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/jadamoureen/genomic_surveillance_malaria_vectors (fetch)
# origin	https://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@github.com/jadamoureen/genomic_surveillance_malaria_vectors (push)

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .
# !git commit -m "Add Colab notebook updates"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git branch
# Out:
# * main

# %%
# !git checkout -b workshop1
# Out:
# Switched to a new branch 'workshop1'

# %%
# !git add .
# !git commit -m "Initial commit for workshop1"
# Out:
# On branch workshop1
# nothing to commit, working tree clean

# %%
# !git push origin workshop1
# Out:
# Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/Jadamoureen/genomic_surveillance_malaria_vectors.git
# remote:
# remote: Create a pull request for 'workshop1' on GitHub by visiting:
# remote:      https://github.com/Jadamoureen/genomic_surveillance_malaria_vectors/pull/new/workshop1
# remote:
# To https://github.com/jadamoureen/genomic_surveillance_malaria_vectors
#  * [new branch]      workshop1 -> workshop1
